# %% [markdown]
# ## ***Coffee Shop Sales Performance, Revenue Optimization & Consumer Purchase Behavior Analytics***
#
# ---

# %% [markdown]
# ## Objective
# The objective of this project is to perform end-to-end sales analytics using Python to identify revenue trends, customer purchasing behavior, product performance, and store-wise sales patterns.
#
# The project aims to help coffee shop management make data-driven decisions regarding inventory management, product strategy, pricing optimization, and sales growth.

# %% [markdown]
# **Problem Statement**
#
# The coffee shop generates a large number of daily transactions across multiple products, categories, and store locations. However, the management lacks clear insights into sales performance, customer purchasing behavior, peak business hours, and product profitability.
#
# Using Python and Data Analytics techniques, this project aims to:
#
# Import and preprocess coffee shop sales data using Pandas.
# Identify and handle missing values, duplicate records, and data inconsistencies.
# Perform Exploratory Data Analysis (EDA) to understand sales trends and customer purchasing patterns.
# Analyze monthly, daily, and hourly sales performance.
# Identify top-selling products and product categories.
# Evaluate store-wise sales performance.
# Determine the relationship between transaction quantity and revenue generation.
# Identify peak business hours and customer purchasing trends.
# Generate visualizations and business insights using Matplotlib and Seaborn.
# Provide data-driven recommendations to improve sales and business performance.

# %% [markdown]
# # ***Expected Outcomes***
#
# The analysis of the Coffee Shop Sales dataset is expected to generate valuable insights into sales performance, customer purchasing behavior, product demand, and store operations.
#
# 1. Enhanced Understanding of Sales Performance
#
# Identify monthly, daily, and hourly sales trends.
#
# Understand how sales fluctuate across different periods.
#
# 2. Improved Data Quality
#
# Detect and handle missing values, duplicate records, and formatting issues.
#
# Create a clean dataset suitable for accurate analysis and decision-making.
#
# 3. Product Performance Analysis
#
# Determine the most popular products based on quantity sold.
#
# Identify products contributing the highest revenue.
#
# Understand customer preferences across product categories.
#
# 4. Revenue Analysis
#
# Measure revenue generated by different products and categories.
#
# Identify the major contributors to overall sales.
#
# Provide recommendations to maximize profitability.
#
# 5. Peak Sales Period Identification
#
# Determine peak business hours.
#
# Identify the busiest days and months.
#
# Help management optimize staffing and inventory planning.
#
# 6. Store Performance Evaluation
#
# Compare sales performance across different store locations.
#
# Identify top-performing and underperforming stores.
#
# Support strategic business decisions.
#
# 7. Customer Purchasing Behavior Analysis
#
# Understand when customers are most likely to purchase products.
#
# Analyze transaction volume and purchase frequency patterns.
#
# 8. Actionable Business Insights
#
# Discover opportunities to increase revenue and improve operational efficiency.
#
# Support data-driven decision-making for business growth.
#
# 9. Strategic Recommendations
#
# Recommend promotional strategies for low-performing products.
#
# Suggest inventory optimization methods.
#
# Provide business strategies to improve sales and customer satisfaction.

# %% [markdown]
# ## Domain
#
# Retail Analytics / Food & Beverage Analytics

# %% [markdown]
# # ***Dataset Column Description***
#
# Column Name      | Description                          |
# | ---------------- | ------------------------------------ |
# | transaction_id   | Unique transaction identifier        |
# | transaction_date | Date of transaction                  |
# | transaction_time | Time of transaction                  |
# | transaction_qty  | Quantity of products purchased       |
# | store_id         | Store identifier                     |
# | store_location   | Store location                       |
# | product_id       | Product identifier                   |
# | unit_price       | Price per unit                       |
# | product_category | Product category                     |
# | product_type     | Product type                         |
# | product_detail   | Product description                  |
# | Sales            | Revenue generated (Qty × Unit Price) |

# %% [markdown]
# # ***Business Questions***
#
# Sales Analysis
#
#  1.Which month generated the highest revenue?
#
#  2.Which day recorded the highest sales?
#
#  3.What are the peak business hours?
#
#  4.Which store location performs best?
#
# Product Analysis
#
#  1.Which products are sold most frequently?
#
#  2.Which product category generates the highest revenue?
#
#  3.Which products contribute the least revenue?
#
#  4.Customer Trend Analysis
#
# Are weekends busier than weekdays?
#
#  1.What time do customers make the most purchases?
#
#  2.Which months generate the highest customer traffic?
#
# Revenue Analysis
#
#  1.What is the total revenue generated by the coffee shop?
#
#  2.Which store contributes the highest revenue?
#
#  3.Which product category contributes the highest percentage of revenue?
#
# Business Improvement Questions
#
#  1.Which products should be promoted to increase sales?
#
#  2.What strategies can improve sales during low-performing periods?

# %% [markdown]
# # ***Stage 1 Completion***
#
# ✅ Problem Definition
#
# ✅ Expected Outcomes
#
# ✅ Dataset Source
#
# ✅ Dataset Description
#
# ✅ Business Questions Defined

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/sivaranjania123-sketch/coffee-shop-business-insights/main/Coffee%20Shop%20Sales.csv"

df = pd.read_csv(url)

print(df.shape)
df.head()
# Out:
# (149116, 10)
#    transaction_id transaction_date  transaction_qty  store_id  \
# 0               1       01-01-2023                2         5
# 1               2       01-01-2023                2         5
# 2               3       01-01-2023                2         5
# 3               4       01-01-2023                1         5
# 4               5       01-01-2023                2         5
#
#     store_location  product_id  unit_price    product_category  \
# 0  Lower Manhattan          32         3.0              Coffee
# 1  Lower Manhattan          57         3.1                 Tea
# 2  Lower Manhattan          59         4.5  Drinking Chocolate
# 3  Lower Manhattan          22         2.0              Coffee
# 4  Lower Manhattan          57         3.1                 Tea
#
#             product_type               product_detail
# 0  Gourmet brewed coffee                  Ethiopia Rg
# 1        Brewed Chai tea     Spicy Eye Opener Chai Lg
# ...

# %%
print("\nDataset Info")
df.info()
# Out:
# Dataset Info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149116 entries, 0 to 149115
# Data columns (total 10 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   transaction_id    149116 non-null  int64
#  1   transaction_date  149116 non-null  object
#  2   transaction_qty   149116 non-null  int64
#  3   store_id          149116 non-null  int64
#  4   store_location    149116 non-null  object
#  5   product_id        149116 non-null  int64
#  6   unit_price        149116 non-null  float64
#  7   product_category  149116 non-null  object
#  8   product_type      149116 non-null  object
#  9   product_detail    149116 non-null  object
# dtypes: float64(1), int64(4), object(5)
# memory usage: 11.4+ MB

# %%
df.describe()
# Out:
#        transaction_id  transaction_qty       store_id     product_id  \
# count   149116.000000    149116.000000  149116.000000  149116.000000
# mean     74737.371872         1.438276       5.342063      47.918607
# std      43153.600016         0.542509       2.074241      17.930020
# min          1.000000         1.000000       3.000000       1.000000
# 25%      37335.750000         1.000000       3.000000      33.000000
# 50%      74727.500000         1.000000       5.000000      47.000000
# 75%     112094.250000         2.000000       8.000000      60.000000
# max     149456.000000         8.000000       8.000000      87.000000
#
#           unit_price
# count  149116.000000
# mean        3.382219
# std         2.658723
# min         0.800000
# 25%         2.500000
# 50%         3.000000
# 75%         3.750000
# max        45.000000

# %%
print("\nDataset Shape")
print(df.shape)
# Out:
# Dataset Shape
# (149116, 11)

# %%
print("\nColumn Names")
print(df.columns)
# Out:
# Column Names
# Index(['transaction_id', 'transaction_date', 'transaction_qty', 'store_id',
#        'store_location', 'product_id', 'unit_price', 'product_category',
#        'product_type', 'product_detail'],
#       dtype='object')

# %%
print("\nMissing Values")
print(df.isnull().sum())
# Out:
# Missing Values
# transaction_id      0
# transaction_date    0
# transaction_qty     0
# store_id            0
# store_location      0
# product_id          0
# unit_price          0
# product_category    0
# product_type        0
# product_detail      0
# Month               0
# dtype: int64

# %%
print("\nDuplicate Records")
print(df.duplicated().sum())
# Out:
# Duplicate Records
# 0

# %%
df.isnull().sum()
# Out:
# transaction_id      0
# transaction_date    0
# transaction_qty     0
# store_id            0
# store_location      0
# product_id          0
# unit_price          0
# product_category    0
# product_type        0
# product_detail      0
# Month               0
# dtype: int64

# %% [markdown]
# # ***Initial EDA***
# # **Dataset Overview**
#
# The Coffee Shop Sales dataset contains transaction-level sales records collected from multiple store locations. The dataset includes information about transaction dates, transaction times, products sold, quantity purchased, unit prices, and store locations.
#
# # ***What was analyzed?***
# Column information
# Data types
# Statistical summary
# Missing values
# Duplicate records
#
# # ***Purpose of Initial EDA***
# The purpose of Initial EDA is to understand the structure and quality of the dataset before performing data cleaning and advanced analysis.
#
# # ***Key Observations***
# Total number of rows and columns were identified.
# Data types were verified.
# Missing values were checked.
# Duplicate records were detected.
# Statistical summary was generated for numerical columns.
#
# # ***Business Importance***
# Understanding the dataset structure helps ensure data quality and supports accurate analysis, visualization, and business decision-making.

# %% [markdown]
# ## *` Stage 2 – Data Cleaning and Pre-processing`*

# %% [markdown]
# # ***Tasks Performed***
#
# ✅ Handle Missing Values
#
# ✅ Check Duplicate Records
#
# ✅ Convert Date Columns
#
# ✅ Create Sales Feature
#
# ✅ Create Month Feature
#
# ✅ Create Quarter Feature
#
# ✅ Create Day Name Feature
#
# ✅ Create Hour Feature

# %%
df['transaction_date'] = pd.to_datetime(
    df['transaction_date'],
    dayfirst=True
)

# %%
df[['transaction_date']].head()
# Out:
#   transaction_date
# 0       2023-01-01
# 1       2023-01-01
# 2       2023-01-01
# 3       2023-01-01
# 4       2023-01-01

# %%
df['Sales'] = df['transaction_qty'] * df['unit_price']

df['Month'] = df['transaction_date'].dt.month_name()

df['Quarter'] = df['transaction_date'].dt.quarter

df['Day_Name'] = df['transaction_date'].dt.day_name()

# %%
sales_q1 = df['Sales'].quantile(0.25)

sales_q2 = df['Sales'].quantile(0.50)

sales_q3 = df['Sales'].quantile(0.75)

df['Sales_Performance'] = pd.cut(
    df['Sales'],
    bins=[0,sales_q1,sales_q2,sales_q3,float('inf')],
    labels=['Low','Medium','High','Excellent']
)

df['Sales_Performance'].value_counts()
# Out:
# Sales_Performance
# Low          46384
# High         45317
# Medium       30885
# Excellent    26530
# Name: count, dtype: int64

# %%
df[['Sales','Month','Quarter','Day_Name']].head()
# Out:
#    Sales    Month  Quarter Day_Name
# 0    6.0  January        1   Sunday
# 1    6.2  January        1   Sunday
# 2    9.0  January        1   Sunday
# 3    2.0  January        1   Sunday
# 4    6.2  January        1   Sunday

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149116 entries, 0 to 149115
# Data columns (total 15 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   transaction_id     149116 non-null  int64
#  1   transaction_date   149116 non-null  datetime64[ns]
#  2   transaction_qty    149116 non-null  int64
#  3   store_id           149116 non-null  int64
#  4   store_location     149116 non-null  object
#  5   product_id         149116 non-null  int64
#  6   unit_price         149116 non-null  float64
#  7   product_category   149116 non-null  object
#  8   product_type       149116 non-null  object
#  9   product_detail     149116 non-null  object
#  10  Month              149116 non-null  object
#  11  Sales              149116 non-null  float64
#  12  Quarter            149116 non-null  int32
#  13  Day_Name           149116 non-null  object
#  14  Sales_Performance  149116 non-null  category
# ...

# %%
df.to_csv('cleaned_coffee_shop_sales.csv', index=False)

print("Data Cleaning Completed Successfully")
print("Final Shape:", df.shape)
# Out:
# Data Cleaning Completed Successfully
# Final Shape: (149116, 15)

# %%
num_cols = ['transaction_qty','unit_price','Sales']

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # ***Summary of Preprocessing Performed***
#
# ✅ Converted transaction_date into datetime format
#
# ✅ Created Sales feature
#
# ✅ Created Month feature
#
# ✅ Created Quarter feature
#
# ✅ Created Day_Name feature
#
# ✅ Dataset prepared for Exploratory Data Analysis
#
# Data Cleaning Completed Successfully

# %% [markdown]
# ### **Stage 3 – Exploratory Data Analysis and Visualizations**

# %%
plt.figure(figsize=(10,5))

sns.boxplot(
    x='product_category',
    y='Sales',
    data=df
)

plt.title('Sales Distribution by Product Category')
plt.xlabel('Product Category')
plt.ylabel('Sales')

plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# # ***Insights***
#
# 1.Sales distribution varies across different product categories.
#
# 2.Some product categories exhibit higher sales variability.
#
# 3.High-value sales transactions are observed in selected categories.
#
# 4.Customer purchasing patterns differ by product category.

# %%
plt.figure(figsize=(10,5))

sns.violinplot(
    x='product_category',
    y='Sales',
    data=df
)

plt.title('Sales Distribution by Product Category')
plt.xlabel('Product Category')
plt.ylabel('Sales')

plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# # ***Insights***
#
# 1.The majority of transactions are concentrated in low and medium sales ranges.
#
# 2.Coffee and Tea categories exhibit wider distributions, indicating higher customer demand.
#
# 3.Product categories show varying levels of sales density and transaction frequency.
#
# 4.Certain categories display occasional high-value transactions.
#
# 5.Customer purchasing behavior differs significantly across product categories.

# %%
pivot = pd.pivot_table(
    df,
    values='Sales',
    index='product_category',
    columns='store_location',
    aggfunc='sum'
)

plt.figure(figsize=(8,5))

sns.heatmap(
    pivot,
    annot=True,
    fmt='.0f'
)

plt.title('Sales Heatmap by Category and Store')

plt.show()

# %% [markdown]
# # ***Insights***
#
# 1.Revenue generation varies considerably among store locations.
#
# 2.Coffee products consistently generate strong revenue across all stores.
#
# 3.Hell's Kitchen store demonstrates superior sales performance.
#
# 4.Product category demand differs based on store location.
#
# 5.Store-specific strategies can improve business performance.

# %%
plt.figure(figsize=(8,5))

sns.scatterplot(
    x='unit_price',
    y='Sales',
    data=df
)

plt.title('Unit Price vs Sales')
plt.xlabel('Unit Price')
plt.ylabel('Sales')

plt.show()

# %% [markdown]
# # ***Insights***
#
# 1.A positive relationship exists between unit price and sales revenue.
#
# 2.Higher-priced products contribute significantly to overall revenue.
#
# 3.Customer purchasing behavior varies across price segments.
#
# 4.Premium products generate higher revenue despite lower purchase frequency.
#
# 5.Pricing strategy has a major impact on business profitability.

# %%
plt.figure(figsize=(6,4))

sns.heatmap(
    df[['transaction_qty','unit_price','Sales']].corr(),
    annot=True,
    cmap='coolwarm'
)

plt.title('Correlation Analysis')

plt.show()

# %% [markdown]
# # ***Insights***
#
# 1.Sales have a strong positive correlation with transaction quantity.
#
# 2.Unit price also contributes positively to revenue generation.
#
# 3.Transaction quantity is the most influential factor affecting sales.
#
# 4.Multiple variables collectively determine business performance.
#
# 5.Correlation analysis supports data-driven decision-making.

# %%
category_sales = df.groupby('product_category')['Sales'].sum()

plt.figure(figsize=(8,8))

plt.pie(
    category_sales.values,
    labels=category_sales.index,
    autopct='%1.1f%%',
    wedgeprops={'width':0.4}
)

plt.title('Revenue Share by Category')

plt.show()

# %% [markdown]
# # ***Insights***
#
# **Revenue Share by Category**
#
# 1.Coffee contributes the highest percentage of total revenue (47.4%).
#
# 2.Tea is the second-largest revenue contributor.
#
# **Top Products**
#
# 1.Barista Espresso is the highest revenue-generating product.
#
# 2.Brewed Chai Tea and Gourmet Brewed Coffee contribute significantly to revenue.
#
# **Store Performance**
#
# 1.Hell's Kitchen store records the highest average transaction value.
#
# 2.Lower Manhattan demonstrates moderate performance.
#
# 3.Astoria records comparatively lower average sales.

# %%
plt.figure(figsize=(8,5))

sns.histplot(
    df['Sales'],
    bins=30
)

plt.title('Sales Distribution')
plt.xlabel('Sales')
plt.ylabel('Frequency')

plt.show()

# %% [markdown]
# # ***Insights***
#
# 1.Most transactions occur within low and medium sales ranges.
#
# 2.High-value transactions occur less frequently.
#
# 3.Customer spending patterns exhibit positive skewness.
#
# 4.The sales distribution is not uniform across customers.
#
# 5.Customer purchase behavior varies significantly.

# %%
monthly_sales = df.groupby('Month')['Sales'].sum()

plt.figure(figsize=(10,5))

plt.fill_between(
    range(len(monthly_sales)),
    monthly_sales.values,
    alpha=0.5
)

plt.plot(monthly_sales.values, marker='o')

plt.title('Monthly Revenue Trend')

plt.show()

# %% [markdown]
# # ***Insights***
#
# 1.Monthly revenue fluctuates over time.
#
# 2.Seasonal patterns influence customer purchasing behavior.
#
# 3.Certain months generate significantly higher revenue.
#
# 4.Revenue trends help identify peak and low business periods.
#
# 5.Seasonal analysis supports inventory and marketing planning.

# %%
top_products = df.groupby('product_detail')['Sales'].sum()\
                 .sort_values(ascending=False)\
                 .head(10)

plt.figure(figsize=(10,5))

sns.barplot(
    x=top_products.values,
    y=top_products.index
)

plt.title('Top 10 Products by Revenue')

plt.show()

# %% [markdown]
# # ***Insights***
#
# 1.Barista Espresso is the highest revenue-generating product.
#
# 2.Brewed Chai Tea and Gourmet Brewed Coffee also contribute substantially.
#
# 3.A small number of products generate a significant portion of revenue.
#
# 4.Premium beverage products perform exceptionally well.
#
# 5.Product-focused marketing strategies can improve profitability

# %%
avg_sales = df.groupby('store_location')['Sales'].mean()

plt.figure(figsize=(8,5))

sns.barplot(
    x=avg_sales.index,
    y=avg_sales.values
)

plt.title('Average Sales per Transaction by Store')

plt.show()

# %% [markdown]
# # ***Insights***
#
# 1.Hell's Kitchen store records the highest average transaction value.
#
# 2.Lower Manhattan demonstrates moderate performance.
#
# 3.Astoria records comparatively lower average sales.
#
# 4.Customer spending behavior varies by location.
#
# 5.Store-level business strategies are required to maximize revenue.

# %%
plt.figure(figsize=(8,5))
sns.countplot(
    x='product_category',
    data=df
)

plt.title('Product Category Count')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # ***Insights***
#
# 1.Coffee category contains the highest number of products available.
#
# 2.Flavours category contains the lowest number of products.
#
# 3.Product assortment varies significantly across categories.
#
# 4.Greater product variety may influence customer purchasing decisions.
#
# 5.Product portfolio management supports business growth.

# %% [markdown]
# ### **STAGE 4 - Documentation, Insights & Presentation**

# %% [markdown]
# ![123334.png](data:image/png;base64,...)

# %% [markdown]
# **4.1 Skewness Analysis Before Treatment**

# %%
num_cols = ['transaction_qty','unit_price','Sales']

print("Skewness Values")

for col in num_cols:
    print(col,":",df[col].skew())
# Out:
# Skewness Values
# transaction_qty : 0.6799290776108677
# unit_price : 0.08631946099821877
# Sales : 0.9000585811656648

# %% [markdown]
# # **Interpretation**
#
# The dataset exhibits positive skewness across all numerical variables.
#
# Transaction quantity shows moderate positive skewness, while unit price and sales display high positive skewness due to a small number of high-value transactions.
#
# These extreme observations may influence statistical analysis and visualization results.

# %% [markdown]
# **4.2 Outlier Detection Before Treatment**

# %%
for col in num_cols:

    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)

    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    outliers = df[(df[col] < lower) | (df[col] > upper)]

    print(f"{col}: {len(outliers)} outliers")
# Out:
# transaction_qty: 0 outliers
# unit_price: 0 outliers
# Sales: 0 outliers

# %% [markdown]
# # **Interpretation**
# Outlier analysis using the IQR method did not detect any significant outliers in the numerical variables. Therefore, no major treatment was required.

# %% [markdown]
# **4.3 Outlier Treatment Using IQR Capping**

# %%
for col in num_cols:

    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)

    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    df[col] = df[col].clip(lower, upper)

print("Outlier Treatment Completed")
# Out:
# Outlier Treatment Completed

# %% [markdown]
# **4.4 Outlier Detection After Treatment**

# %%
for col in num_cols:

    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)

    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    outliers = df[(df[col] < lower) | (df[col] > upper)]

    print(f"{col}: {len(outliers)} outliers")
# Out:
# transaction_qty: 0 outliers
# unit_price: 0 outliers
# Sales: 0 outliers

# %% [markdown]
# # **Interpretation**
# The IQR-based capping method successfully controlled extreme observations.
#
# After treatment, no values remained outside the acceptable range, resulting in improved data quality.

# %% [markdown]
# **4.5 Skewness Analysis After Treatment**

# %%
print("Skewness After Treatment")

for col in num_cols:
    print(col,":",df[col].skew())
# Out:
# Skewness After Treatment
# transaction_qty : 0.6799290776108677
# unit_price : 0.08631946099821877
# Sales : 0.9000585811656648

# %% [markdown]
# # **Interpretation**
# The skewness values remained almost unchanged after treatment because no significant outliers were detected by the IQR method.

# %% [markdown]
# # **Stage 5 – Key Findings**
#
#
# 1. Coffee products generated the highest revenue.
# 2. Sales performance varied across product categories and store locations.
# 3. Premium-priced products contributed significantly to total revenue.
# 4. Customer purchases were concentrated in low and medium transaction values.
# 5. Monthly sales trends revealed periods of high and low business activity.
# 6. No significant outliers were detected using the IQR method.
# 7. Product variety influences customer purchasing behavior.

# %% [markdown]
# # ***Business Recommendations***
#
# 1. Promote top-selling coffee products through combo offers.
# 2. Increase inventory during peak sales periods.
# 3. Offer discounts during low-performing periods.
# 4. Focus marketing efforts on underperforming stores.
# 5. Implement customer loyalty programs.
# 6. Optimize staffing based on customer demand patterns.
# 7. Expand product categories with high customer interest.

# %% [markdown]
# # **Conclusion**
#
# The Coffee Shop Sales Analytics project successfully analyzed sales performance, customer purchasing behavior, product demand, and revenue trends.
#
# The analysis identified high-performing products, key revenue contributors, and store-wise sales patterns.
#
# Skewness and outlier analysis improved data quality by reducing the impact of extreme observations.
#
# The insights generated from this project can support inventory planning, pricing optimization, customer engagement strategies, and long-term business growth.
#
# This project demonstrates the practical application of Python, Pandas, Matplotlib, and Seaborn for end-to-end business analytics and data-driven decision-making.
